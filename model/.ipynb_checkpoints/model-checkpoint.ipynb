# %%
# !pip install opencv-contrib-python
# Out:
# ...
#   Using cached opencv_contrib_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
pip install PyWavelets
# Out:
# ...
#   Using cached pywavelets-1.9.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 9.1 kB/s eta 0:00:00m eta 0:00:04m:--5:49
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
import cv2
import matplotlib.pyplot as plt
import seaborn

# %matplotlib inline

# %%
img = cv2.imread('./images_dataset/bruce_molodie/bruce.jpeg')

img.shape
# Out:
# [ WARN:0@98.554] global loadsave.cpp:278 findDecoder imread_('./images_dataset/bruce_molodie/bruce.jpeg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 img = cv2.imread('./images_dataset/bruce_molodie/bruce.jpeg')
# ----> 3 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'
