# %%
pip install opencv-contrib-python
# Out:
# ...
#    ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/79.2 MB 12.3 kB/s eta 1:42:01

# %%
pip install PyWavelets

# %%
import numpy
import cv2
import matplotlib.pyplot as plt
import seaborn

# %matplotlib inline
